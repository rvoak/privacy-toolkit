# %%
import KAnonymity
import LDiversity
import pandas as pd

# %% [markdown]
# ## Load Sample Data

# %%
DATA_PATH = 'sample_data.csv'
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#   Gender  Age Marital_Status Country_Birth                Race  Alcohol Average/Day Ever Used Hard Drugs
# 0      F   30        Married         Other      Other Hispanic                    3                   No
# 1      F   30        Married            US  Non-Hispanic White                    3                   No
# 2      F   30  Never Married         Other  Non-Hispanic Black                    2                   No
# 3      F   30  Never Married         Other               Other                    4                   No
# 4      F   30  Never Married            US  Non-Hispanic Black                    2                   No

# %% [markdown]
# ## K-Anonymity

# %% [markdown]
# ### Determine the value of k for some set of quasi identifiers

# %%
quasi = ['Age','Country_Birth']
k = KAnonymity.get_k_anonymity(df,quasi)

# %%
k['k']
# Out:
# 8

# %%
k['equivalence_classes']
# Out:
# [(30, 'Other')]

# %% [markdown]
# ### Examine k-values for various sets of quasi-identifiers

# %%
KAnonymity.get_k_summary(df,as_df=True)
# Out:
# /Users/rajvardhan/Desktop/privacy-library/KAnonymity.py:30: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#   df_grouped = df_local.groupby(quasi_identifiers).count()
#                                      Quasi_Identifiers   K
# 0                                            (Gender,)  21
# 1                                               (Age,)  14
# 2                                    (Marital_Status,)   2
# 3                                     (Country_Birth,)  20
# 4                                              (Race,)   2
# 5                               (Alcohol Average/Day,)   1
# 6                              (Ever Used Hard Drugs,)  16
# 7                                        (Gender, Age)   7
# 8                             (Gender, Marital_Status)   2
# 9                              (Gender, Country_Birth)   5
# ...
